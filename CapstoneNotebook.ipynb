# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods Notebook

# %% [markdown]
# ## Introduction

# %% [markdown]
# - Objective: we will analize Youngstown City neighborhoods to select the best locations to open three new grocery stores.

# %% [markdown]
# - First, we load the data.

# %% [markdown]
# - Then, we will add latitude and longtitude to it.

# %% [markdown]
# - We will do survey on which neighborhoods lack grocery store.

# %% [markdown]
# - Lastly, we will select the top three neighborhoods to open new grocery stores.

# %% [markdown]
# ### Import libraries

# %%
conda install -c anaconda beautifulsoup4
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.3       |     pyhb0f4dca_0          87 KB  anaconda
#     ca-certificates-2020.10.14 |                0         128 KB  anaconda
#     certifi-2020.6.20          |           py36_0         160 KB  anaconda
#     openssl-1.1.1k             |       h7f98852_0         2.1 MB  conda-forge
#     soupsieve-2.0.1            |             py_0          33 KB  anaconda
#     ------------------------------------------------------------
# ...

# %%
conda update -n base conda
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /srv/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py38h497a2fe_1001         341 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
#     cffi-1.14.5                |   py38ha65f79e_0         227 KB  conda-forge
#     chardet-4.0.0              |   py38h578d9bd_1         199 KB  conda-forge
#     conda-4.10.1               |   py38h578d9bd_0         3.1 MB  conda-forge
#     conda-package-handling-1.7.3|   py38h497a2fe_0         927 KB  conda-forge
#     cryptography-3.4.7         |   py38ha5dfef3_0         1.1 MB  conda-forge
# ...

# %%
pip install geopy
# Out:
# ...
#      |████████████████████████████████| 112 kB 4.2 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# ...
#      |████████████████████████████████| 94 kB 2.0 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### List of postal codes in Youngstown Area

# %%
url = 'https://www.zipdatamaps.com/zipcodes-youngstown-oh'
data = requests.get(url)
soup = BeautifulSoup(data.text)
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
       

# print(table_contents)
df=pd.DataFrame(table_contents)
# Out:
#   File "<ipython-input-16-d468cbc0edfe>", line 14
#     df=pd.DataFrame(table_contents)
#                                    ^
# IndentationError: expected an indented block
